# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../dataset/T_20_data.csv")

# %%
df.head()
# Out:
#    comment_id  match_id match_name home_team away_team current_innings  \
# 0         130   1298179  ENG v PAK       PAK       ENG             PAK
# 1         120   1298179  ENG v PAK       PAK       ENG             PAK
# 2         110   1298179  ENG v PAK       PAK       ENG             PAK
# 3         140   1298179  ENG v PAK       PAK       ENG             PAK
# 4         150   1298179  ENG v PAK       PAK       ENG             PAK
#
#    innings_id  over  ball  runs  ... wicket_id  wkt_batsman_name  \
# 0           1     1     1     0  ...       NaN               NaN
# 1           1     1     1     1  ...       NaN               NaN
# 2           1     1     1     1  ...       NaN               NaN
# 3           1     1     2     2  ...       NaN               NaN
# 4           1     1     3     0  ...       NaN               NaN
#
#    wkt_bowler_name  wkt_batsman_runs  wkt_batsman_balls wkt_text  \
# 0              NaN               NaN                NaN      NaN
# 1              NaN               NaN                NaN      NaN
# 2              NaN               NaN                NaN      NaN
# 3              NaN               NaN                NaN      NaN
# 4              NaN               NaN                NaN      NaN
#
#    isRetiredHurt                                               text  \
# 0          False  short again, and he gets some extra bounce on ...
# 1          False  and he'll have to bowl another free-hit after ...
# 2          False  full, and a hint of shape away from off stump....
# 3          False  shortish, angling down leg, gloves a pull down...
# 4          False  length ball close to off stump, straightens a ...
#
#                                              preText postText
# 0                                                NaN      NaN
# 1                                    <p>Free-hit</p>      NaN
# 2  <p><b>6.58pm</b> Thanks, Andrew M. The MCG is ...      NaN
# 3                                                NaN      NaN
# 4                                                NaN      NaN
#
# [5 rows x 44 columns]

# %%
df.describe()
# Out:
#           comment_id      match_id   innings_id         over         ball  \
# count    9814.000000  9.814000e+03  9814.000000  9814.000000  9814.000000
# mean    85399.661708  1.298157e+06     1.477787    10.082841     3.486856
# std     78951.670137  1.355630e+01     0.499532     5.623045     1.707484
# min       110.000000  1.298135e+06     1.000000     1.000000     1.000000
# 25%     18030.000000  1.298145e+06     1.000000     5.000000     2.000000
# 50%     29010.000000  1.298157e+06     1.000000    10.000000     3.000000
# 75%    118040.000000  1.298169e+06     2.000000    15.000000     5.000000
# max    219090.000000  1.298179e+06     2.000000    20.000000     6.000000
#
#               runs   batsman1_id  batsman1_runs  batsman1_balls    bowler1_id  \
# count  9814.000000  9.814000e+03    9814.000000     9814.000000  9.814000e+03
# mean      1.202262  5.377303e+05      15.691971       13.249440  6.226676e+05
# std       1.476730  3.181419e+05      16.454378       11.471307  3.276842e+05
# min       0.000000  5.334000e+03       0.000000        0.000000  8.917000e+03
# 25%       0.000000  3.089670e+05       4.000000        4.000000  3.481090e+05
# 50%       1.000000  4.465070e+05      10.000000       10.000000  5.420230e+05
# 75%       1.000000  7.843670e+05      23.000000       19.000000  9.229430e+05
# max       7.000000  1.278252e+06     109.000000       63.000000  1.278252e+06
#
#        ...  batsman2_runs  batsman2_balls    bowler2_id  bowler2_overs  \
# count  ...    9814.000000     9814.000000  9.288000e+03    9288.000000
# mean   ...      14.978296       12.738537  6.216881e+05       2.172265
# std    ...      16.376065       11.596212  3.287888e+05       1.039511
# min    ...       0.000000        0.000000  8.917000e+03       0.100000
# 25%    ...       2.000000        4.000000  3.481090e+05       1.000000
# 50%    ...       9.000000        9.000000  5.420230e+05       2.000000
# 75%    ...      23.000000       19.000000  9.229430e+05       3.000000
# max    ...     107.000000       63.000000  1.278252e+06       4.000000
#
#        bowler2_maidens  bowler2_runs  bowler2_wkts     wicket_id  \
# count      9288.000000   9288.000000   9288.000000  5.510000e+02
# mean          0.031654     14.684755      0.641042  5.691470e+05
# std           0.182317      9.366489      0.833070  3.305531e+05
# min           0.000000      0.000000      0.000000  5.334000e+03
# 25%           0.000000      7.000000      0.000000  3.233890e+05
# 50%           0.000000     13.000000      0.000000  4.824780e+05
# 75%           0.000000     20.000000      1.000000  8.337770e+05
# max           2.000000     59.000000      4.000000  1.278252e+06
#
#        wkt_batsman_runs  wkt_batsman_balls
# count        551.000000         551.000000
# mean          15.029038          13.800363
# std           16.466801          11.707343
# min            0.000000           1.000000
# 25%            3.000000           5.000000
# 50%            9.000000          10.000000
# 75%           21.000000          19.000000
# max          109.000000          60.000000
#
# [8 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9814 entries, 0 to 9813
# Data columns (total 44 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   comment_id         9814 non-null   int64
#  1   match_id           9814 non-null   int64
#  2   match_name         9814 non-null   object
#  3   home_team          9814 non-null   object
#  4   away_team          9814 non-null   object
#  5   current_innings    9814 non-null   object
#  6   innings_id         9814 non-null   int64
#  7   over               9814 non-null   int64
#  8   ball               9814 non-null   int64
#  9   runs               9814 non-null   int64
#  10  shortText          9814 non-null   object
#  11  isBoundary         9814 non-null   bool
#  12  isWide             9814 non-null   bool
#  13  isNoball           9814 non-null   bool
#  14  batsman1_id        9814 non-null   int64
#  15  batsman1_name      9814 non-null   object
#  16  batsman1_runs      9814 non-null   int64
#  17  batsman1_balls     9814 non-null   int64
#  18  bowler1_id         9814 non-null   int64
#  19  bowler1_name       9814 non-null   object
#  20  bowler1_overs      9814 non-null   float64
#  21  bowler1_maidens    9814 non-null   int64
#  22  bowler1_runs       9814 non-null   int64
#  23  bowler1_wkts       9814 non-null   int64
#  24  batsman2_id        9814 non-null   int64
#  25  batsman2_name      9814 non-null   object
#  26  batsman2_runs      9814 non-null   int64
#  27  batsman2_balls     9814 non-null   int64
#  28  bowler2_id         9288 non-null   float64
#  29  bowler2_name       9288 non-null   object
#  30  bowler2_overs      9288 non-null   float64
#  31  bowler2_maidens    9288 non-null   float64
#  32  bowler2_runs       9288 non-null   float64
#  33  bowler2_wkts       9288 non-null   float64
#  34  wicket_id          551 non-null    float64
#  35  wkt_batsman_name   551 non-null    object
#  36  wkt_bowler_name    551 non-null    object
#  37  wkt_batsman_runs   551 non-null    float64
#  38  wkt_batsman_balls  551 non-null    float64
#  39  wkt_text           551 non-null    object
#  40  isRetiredHurt      9814 non-null   bool
#  41  text               9786 non-null   object
#  42  preText            1861 non-null   object
#  43  postText           1088 non-null   object
# dtypes: bool(4), float64(9), int64(16), object(15)
# memory usage: 3.0+ MB

# %%
df.isnull().sum()
# Out:
# comment_id              0
# match_id                0
# match_name              0
# home_team               0
# away_team               0
# current_innings         0
# innings_id              0
# over                    0
# ball                    0
# runs                    0
# shortText               0
# isBoundary              0
# isWide                  0
# isNoball                0
# batsman1_id             0
# batsman1_name           0
# batsman1_runs           0
# batsman1_balls          0
# bowler1_id              0
# bowler1_name            0
# bowler1_overs           0
# bowler1_maidens         0
# bowler1_runs            0
# bowler1_wkts            0
# batsman2_id             0
# batsman2_name           0
# batsman2_runs           0
# batsman2_balls          0
# bowler2_id            526
# bowler2_name          526
# bowler2_overs         526
# bowler2_maidens       526
# bowler2_runs          526
# bowler2_wkts          526
# wicket_id            9263
# wkt_batsman_name     9263
# wkt_bowler_name      9263
# wkt_batsman_runs     9263
# wkt_batsman_balls    9263
# wkt_text             9263
# isRetiredHurt           0
# text                   28
# preText              7953
# postText             8726
# dtype: int64

# %% [markdown]
# remove missing value

# %%
df['bowler2_id'].fillna(df.groupby(['bowler1_id'])['bowler2_id'].transform('mean'), inplace=True)
df['bowler2_name'].fillna(df.groupby(['bowler1_name'])['bowler2_name'].transform(lambda x: x.mode().iloc[0]), inplace=True)
df['bowler2_overs'].fillna(df.groupby(['bowler1_name'])['bowler2_overs'].transform('median'), inplace=True)
df['bowler2_runs'].fillna(df.groupby(['bowler1_name'])['bowler2_runs'].transform('median'), inplace=True)
print(df)
# Out:
#       comment_id  match_id match_name home_team away_team current_innings  \
# 0            130   1298179  ENG v PAK       PAK       ENG             PAK
# 1            120   1298179  ENG v PAK       PAK       ENG             PAK
# 2            110   1298179  ENG v PAK       PAK       ENG             PAK
# 3            140   1298179  ENG v PAK       PAK       ENG             PAK
# 4            150   1298179  ENG v PAK       PAK       ENG             PAK
# ...          ...       ...        ...       ...       ...             ...
# 9809      218020   1298135   NAM v SL       NAM        SL              SL
# 9810      218030   1298135   NAM v SL       NAM        SL              SL
# 9811      218040   1298135   NAM v SL       NAM        SL              SL
# 9812      218050   1298135   NAM v SL       NAM        SL              SL
# 9813      218060   1298135   NAM v SL       NAM        SL              SL
#
#       innings_id  over  ball  runs  ... wicket_id     wkt_batsman_name  \
# 0              1     1     1     0  ...       NaN                  NaN
# 1              1     1     1     1  ...       NaN                  NaN
# 2              1     1     1     1  ...       NaN                  NaN
# 3              1     1     2     2  ...       NaN                  NaN
# 4              1     1     3     0  ...       NaN                  NaN
# ...          ...   ...   ...   ...  ...       ...                  ...
# 9809           2    19     2     1  ...       NaN                  NaN
# 9810           2    19     3     0  ...       NaN                  NaN
# 9811           2    19     4     0  ...       NaN                  NaN
# 9812           2    19     5     0  ...       NaN                  NaN
# 9813           2    19     6     0  ...  552152.0  Dushmantha Chameera
#
#       wkt_bowler_name  wkt_batsman_runs  wkt_batsman_balls  \
# 0                 NaN               NaN                NaN
# 1                 NaN               NaN                NaN
# 2                 NaN               NaN                NaN
# 3                 NaN               NaN                NaN
# 4                 NaN               NaN                NaN
# ...               ...               ...                ...
# 9809              NaN               NaN                NaN
# 9810              NaN               NaN                NaN
# 9811              NaN               NaN                NaN
# 9812              NaN               NaN                NaN
# 9813      David Wiese               8.0               15.0
#
#                                                wkt_text  isRetiredHurt  \
# 0                                                   NaN          False
# 1                                                   NaN          False
# 2                                                   NaN          False
# 3                                                   NaN          False
# 4                                                   NaN          False
# ...                                                 ...            ...
# 9809                                                NaN          False
# 9810                                                NaN          False
# 9811                                                NaN          False
# 9812                                                NaN          False
# 9813  PVD Chameera c Erasmus b Wiese 8 (20m 15b 0x4 ...          False
#
#                                                    text  \
# 0     short again, and he gets some extra bounce on ...
# 1     and he'll have to bowl another free-hit after ...
# 2     full, and a hint of shape away from off stump....
# 3     shortish, angling down leg, gloves a pull down...
# 4     length ball close to off stump, straightens a ...
# ...                                                 ...
# 9809  slower ball on a length, waits for this and op...
# 9810  another slower ball, keeps very low. Bounces t...
# 9811  Almost cleans him up! Yorker finds it's way pa...
# 9812       short ball, goes for the uppercut and misses
# 9813  <b>And that's that!</b> Chameera looks to swin...
#
#                                                 preText  \
# 0                                                   NaN
# 1                                       <p>Free-hit</p>
# 2     <p><b>6.58pm</b> Thanks, Andrew M. The MCG is ...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9809                                                NaN
# 9810                                                NaN
# 9811                                                NaN
# 9812                                                NaN
# 9813                                                NaN
#
#                                                postText
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9809                                                NaN
# 9810                                                NaN
# 9811                                                NaN
# 9812                                                NaN
# 9813  <p>And on that note, it's goodbye from myself,...
#
# [9814 rows x 44 columns]
# C:\Users\Sanjhana\AppData\Local\Temp\ipykernel_33116\3641329361.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bowler2_id'].fillna(df.groupby(['bowler1_id'])['bowler2_id'].transform('mean'), inplace=True)
# C:\Users\Sanjhana\AppData\Local\Temp\ipykernel_33116\3641329361.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bowler2_name'].fillna(df.groupby(['bowler1_name'])['bowler2_name'].transform(lambda x: x.mode().iloc[0]), inplace=True)
# C:\Users\Sanjhana\AppData\Local\Temp\ipykernel_33116\3641329361.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bowler2_overs'].fillna(df.groupby(['bowler1_name'])['bowler2_overs'].transform('median'), inplace=True)
# C:\Users\Sanjhana\AppData\Local\Temp\ipykernel_33116\3641329361.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bowler2_runs'].fillna(df.groupby(['bowler1_name'])['bowler2_runs'].transform('median'), inplace=True)

# %% [markdown]
# EDA

# %%
best_team = df.groupby('current_innings')['runs'].sum().reset_index()

# Plotting the graph
plt.figure(figsize=(10, 6))
plt.bar(best_team['current_innings'], best_team['runs'], color='skyblue')
plt.xlabel('Teams')
plt.ylabel('Total Runs')
plt.title('Total Runs scored by Inning Team')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
df['combined'] = df['batsman1_name'] + ' ' + df['batsman1_runs'].astype(str)

# Calculate the total combined runs
total_combined_runs = df['combined'].sum()

# Plot the graph
plt.figure(figsize=(10, 6))
plt.bar(df['batsman1_name'], df['batsman1_runs'], color='skyblue')
plt.xlabel('Batsman Name')
plt.ylabel('Runs')
plt.title('Runs Scored by Each Batsman')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
first_match_details = df.iloc[1]
print("Details of the First Match:")
print(first_match_details)
# Out:
# Details of the First Match:
# comment_id                                                         120
# match_id                                                       1298179
# match_name                                                   ENG v PAK
# home_team                                                          PAK
# away_team                                                          ENG
# current_innings                                                    PAK
# innings_id                                                           1
# over                                                                 1
# ball                                                                 1
# runs                                                                 1
# shortText                            Stokes to Mohammad Rizwan, 1 wide
# isBoundary                                                       False
# isWide                                                            True
# isNoball                                                         False
# batsman1_id                                                     323389
# batsman1_name                                          Mohammad Rizwan
# batsman1_runs                                                        0
# batsman1_balls                                                       1
# bowler1_id                                                      311158
# bowler1_name                                                Ben Stokes
# bowler1_overs                                                      0.0
# bowler1_maidens                                                      0
# bowler1_runs                                                         2
# bowler1_wkts                                                         0
# batsman2_id                                                     348144
# batsman2_name                                               Babar Azam
# batsman2_runs                                                        0
# batsman2_balls                                                       0
# bowler2_id                                               264022.271429
# bowler2_name                                               Adil Rashid
# bowler2_overs                                                      3.0
# bowler2_maidens                                                    NaN
# bowler2_runs                                                      16.0
# bowler2_wkts                                                       NaN
# wicket_id                                                          NaN
# wkt_batsman_name                                                   NaN
# wkt_bowler_name                                                    NaN
# wkt_batsman_runs                                                   NaN
# wkt_batsman_balls                                                  NaN
# wkt_text                                                           NaN
# isRetiredHurt                                                    False
# text                 and he'll have to bowl another free-hit after ...
# preText                                                <p>Free-hit</p>
# postText                                                           NaN
# combined                                             Mohammad Rizwan 0
# Name: 1, dtype: object

# %%
balls_per_inning = df.groupby('innings_id').size()

# Plotting graph
plt.figure(figsize=(10, 6))
balls_per_inning.plot(kind='bar', color='skyblue')
plt.xlabel('Innings ID')
plt.ylabel('Number of Balls Bowled')
plt.title('Number of Balls Bowled in Each Inning')
plt.grid(True)
plt.tight_layout()
plt.show()

# Displaying total balls bowled
print("Total Balls Bowled in Each Inning:\n", balls_per_inning)
# Out:
# Total Balls Bowled in Each Inning:
#  innings_id
# 1    5125
# 2    4689
# dtype: int64

# %%
top_10_batsmen = df.sort_values(by='runs', ascending=False).head(10)

# Plot graph
plt.figure(figsize=(10, 6))
plt.bar(top_10_batsmen['batsman1_name'], top_10_batsmen['runs'], color='skyblue')
plt.xlabel('Batsman Name')
plt.ylabel('Runs Scored')
plt.title('Top 10 Batsmen by Runs Scored')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
top_bowlers = df.groupby('bowler1_name')['over'].sum().nlargest(10)

plt.figure(figsize=(10, 6))
plt.bar(top_bowlers.index, top_bowlers.values, color='skyblue')
plt.xlabel('Bowler Name')
plt.ylabel('Total Overs Bowled')
plt.title('Top 10 Bowlers by Total Overs Bowled')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Displaying top bowlers
print("Top 10 Bowlers by Total Overs Bowled:\n", top_bowlers)
# Out:
# Top 10 Bowlers by Total Overs Bowled:
#  bowler1_name
# Wanindu Hasaranga de Silva    2127
# Maheesh Theekshana            2038
# Bas de Leede                  1866
# Paul van Meekeren             1824
# Haris Rauf                    1814
# Sam Curran                    1757
# Richard Ngarava               1753
# Sikandar Raza                 1707
# Barry McCarthy                1656
# Blessing Muzarabani           1641
# Name: over, dtype: int64

# %%
inning1_summary = df.groupby(['innings_id']).sum()[['isWide', 'isBoundary', 'isNoball']]

# Plot graph
fig, axes = plt.subplots(3, 1, figsize=(5,6), sharex=True)

# Plot for wide
inning1_summary['isWide'].plot(kind='bar', ax=axes[0], color='r')
axes[0].set_title('iswide')
axes[0].set_ylabel('Count')
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

# Plot for boundary
inning1_summary['isBoundary'].plot(kind='bar', ax=axes[1], color='g')
axes[1].set_title('isboundary')
axes[1].set_ylabel('Count')
axes[1].grid(axis='y', linestyle='--', alpha=0.7)

# Plot for no ball
inning1_summary['isNoball'].plot(kind='bar', ax=axes[2], color='b')
axes[2].set_title('No Ball')
axes[2].set_ylabel('Count')
axes[2].grid(axis='y', linestyle='--', alpha=0.7)

plt.xlabel('Innings ID')
plt.tight_layout()
plt.show()
